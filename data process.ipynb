# %%
# import lib
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
data = pd.read_csv('/content/movie_metadata.csv')
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#checking shape of data
data.shape
# Out:
# (5043, 28)

# %%
#checking name of columns
data.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
# checking movie year in our dataset, which is up to 2016

import matplotlib.pyplot as plt
data.title_year.value_counts(dropna = False).sort_index().plot(kind='barh',figsize=(15,16))
plt.show()

# %%
# selecting the features we use in our recommendation model
data = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
data.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker                   NaN
#
#                             genres  \
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4                      Documentary
#
#                                          movie_title
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# ...

# %%
#checking the missing value
data.isna().sum()
# Out:
# director_name    104
# actor_1_name       7
# actor_2_name      13
# actor_3_name      23
# genres             0
# movie_title        0
# dtype: int64

# %%
# replace the missing value as unknown

data['actor_1_name'] = data['actor_1_name'].replace(np.nan, 'unknown')
data['actor_2_name'] = data['actor_2_name'].replace(np.nan, 'unknown')
data['actor_3_name'] = data['actor_3_name'].replace(np.nan, 'unknown')
data['director_name'] = data['director_name'].replace(np.nan, 'unknown')

# %%
# rechecking the missing value
data.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# dtype: int64

# %%
#replace '|' in our dataset as ' '

data['genres'] = data['genres'].str.replace('|', ' ')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# change all movie title'' into lower caps
data['movie_title'] = data['movie_title'].str.lower()

# %%
# find out there is null terminating char at movie title
data['movie_title'][1]
# Out:
# "pirates of the caribbean: at world's end\xa0"

# %%
# delete the null terminating char at movie title
data['movie_title'] = data['movie_title'].apply(lambda x : x[:-1])

# %%
# recheck
data['movie_title'][1]
# Out:
# "pirates of the caribbean: at world's end"

# %%
# save
data.to_csv('data1.csv',index=False)

# %%
# loading other dataset
credits = pd.read_csv('/content/credits.csv')
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
meta = pd.read_csv('/content/movies_metadata.csv')
meta.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
# change release date to datetime format, 
meta['release_date'] = pd.to_datetime(meta['release_date'], errors='coerce') 
#‘coerce’, then invalid parsing will be set as NaN, ‘raise’, then invalid parsing will raise an exception,
#‘ignore’, then invalid parsing will return the input

# %%
# generate year data
meta['year'] = meta['release_date'].dt.year
meta['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
# Getting 2017 movies
new_meta = meta.loc[meta.year == 2017,['genres','id','title','year']]
new_meta.head()
# Out:
#                                                   genres      id  \
# 26560  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  166426
# 26561  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  141052
# 26565  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  284053
# 26566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  283995
# 30536  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...  245842
#
#                                                   title    year
# 26560  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 26561                                    Justice League  2017.0
# 26565                                    Thor: Ragnarok  2017.0
# 26566                    Guardians of the Galaxy Vol. 2  2017.0
# 30536                               The King's Daughter  2017.0

# %%
# checking the type of variable
new_meta.dtypes
# Out:
# genres     object
# id         object
# title      object
# year      float64
# dtype: object

# %%
#convert the "id" as integer
new_meta['id'] = new_meta['id'].astype(int)

# %%
#combine two dataset by 'id'
data = pd.merge(new_meta, credits, on='id')

# %%
#checing the merged data
pd.set_option('display.max_colwidth', 75)
data
# Out:
#                                                                          genres  \
# 0    [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': ...
# 1    [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 2    [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 3    [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 4    [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'name': 'Action'}, {'id': 12...
# ..                                                                          ...
# 526            [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 527  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}, {'id': 28, ...
# 528  [{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id...
# 529  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, '...
# 530                                                                          []
#
# ...

# %%
# convert the "genre", "cast" and "crew" column into a list
#the "literal_eval" helps to convert the string into a list
import ast
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))  
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
#take out the individual genres like adventure, action, sci-fi, etc. using the following function

def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction': #renaming the "Science Fiction" to "Sci-Fi"
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen)) #join them together with the space and return the valuse

# %%
#apply the function on the genre
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

# %%
# checking the g
data['genres_list']
# Out:
# 0      Adventure Action Fantasy Comedy
# 1      Action Adventure Fantasy Sci-Fi
# 2      Action Adventure Fantasy Sci-Fi
# 3       Action Adventure Comedy Sci-Fi
# 4             Fantasy Action Adventure
#                     ...
# 526                     Romance Comedy
# 527         Crime Comedy Action Family
# 528    Family Animation Romance Comedy
# 529               Crime Drama Thriller
# 530                                NaN
# Name: genres_list, Length: 531, dtype: object

# %%
#do the same for other variables

def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == []:
        return np.NaN
    else:
        return (casts[0])


def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[1])


def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return (casts[2])


def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
#apply it

data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
#checking outcome
data['actor_1_name']
# Out:
# 0               Johnny Depp
# 1               Ben Affleck
# 2           Chris Hemsworth
# 3               Chris Pratt
# 4            Pierce Brosnan
#                ...
# 526          Inka Haapamäki
# 527    Lou Diamond Phillips
# 528                     NaN
# 529          Sridevi Kapoor
# 530                     NaN
# Name: actor_1_name, Length: 531, dtype: object

# %%
data['actor_2_name']
# Out:
# 0       Javier Bardem
# 1        Henry Cavill
# 2      Tom Hiddleston
# 3         Zoe Saldana
# 4        William Hurt
#             ...
# 526     Rosa Honkonen
# 527     Wallace Shawn
# 528               NaN
# 529         Sajal Ali
# 530               NaN
# Name: actor_2_name, Length: 531, dtype: object

# %%
data['actor_3_name']
# Out:
# 0        Geoffrey Rush
# 1            Gal Gadot
# 2       Cate Blanchett
# 3        Dave Bautista
# 4      Benjamin Walker
#             ...
# 526     Tiitus Rantala
# 527        Gina Holden
# 528                NaN
# 529     Akshaye Khanna
# 530                NaN
# Name: actor_3_name, Length: 531, dtype: object

# %%
data['director_name']
# Out:
# 0      Joachim Rønning Espen Sandberg
# 1                         Zack Snyder
# 2                       Taika Waititi
# 3                          James Gunn
# 4                       Sean McNamara
#                     ...
# 526                  Hannaleena Hauru
# 527             Jonathan A. Rosenbaum
# 528          Beth David Esteban Bravo
# 529                      Ravi Udyawar
# 530                     Daisy Asquith
# Name: director_name, Length: 531, dtype: object

# %%
#selecting variables
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]
movie
# Out:
#                       director_name          actor_1_name    actor_2_name  \
# 0    Joachim Rønning Espen Sandberg           Johnny Depp   Javier Bardem
# 1                       Zack Snyder           Ben Affleck    Henry Cavill
# 2                     Taika Waititi       Chris Hemsworth  Tom Hiddleston
# 3                        James Gunn           Chris Pratt     Zoe Saldana
# 4                     Sean McNamara        Pierce Brosnan    William Hurt
# ..                              ...                   ...             ...
# 526                Hannaleena Hauru        Inka Haapamäki   Rosa Honkonen
# 527           Jonathan A. Rosenbaum  Lou Diamond Phillips   Wallace Shawn
# 528        Beth David Esteban Bravo                   NaN             NaN
# 529                    Ravi Udyawar        Sridevi Kapoor       Sajal Ali
# 530                   Daisy Asquith                   NaN             NaN
#
#         actor_3_name                      genres_list  \
# ...

# %%
# checking missing value
movie.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# title            0
# dtype: int64

# %%
#drop missing values
movie = movie.dropna(how='any')

# %%
#renaming for merge
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})

# %%
#convert movie titles to lower caps
movie['movie_title'] = movie['movie_title'].str.lower()

# %%
#combine all information later for the tfidvectorizor
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['genres']
movie
# Out:
#                       director_name          actor_1_name  \
# 0    Joachim Rønning Espen Sandberg           Johnny Depp
# 1                       Zack Snyder           Ben Affleck
# 2                     Taika Waititi       Chris Hemsworth
# 3                        James Gunn           Chris Pratt
# 4                     Sean McNamara        Pierce Brosnan
# ..                              ...                   ...
# 524                     Jim Strouse      Jessica Williams
# 525                     Farhad Mann         Adelaide Kane
# 526                Hannaleena Hauru        Inka Haapamäki
# 527           Jonathan A. Rosenbaum  Lou Diamond Phillips
# 529                    Ravi Udyawar        Sridevi Kapoor
#
#                actor_2_name       actor_3_name  \
# 0             Javier Bardem      Geoffrey Rush
# 1              Henry Cavill          Gal Gadot
# 2            Tom Hiddleston     Cate Blanchett
# 3               Zoe Saldana      Dave Bautista
# ...

# %%
old = pd.read_csv('data1.csv')
old['comb'] = old['actor_1_name'] + ' ' + old['actor_2_name'] + ' '+ old['actor_3_name'] + ' '+ old['director_name'] +' ' + old['genres']
old
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039            unknown      Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
#merge all datasets together and drop the duplicated movie

new = old.append(movie)
new.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)
new
# Out:
#              director_name          actor_1_name            actor_2_name  \
# 0            James Cameron           CCH Pounder        Joel David Moore
# 1           Gore Verbinski           Johnny Depp           Orlando Bloom
# 2               Sam Mendes       Christoph Waltz            Rory Kinnear
# 3        Christopher Nolan             Tom Hardy          Christian Bale
# 4              Doug Walker           Doug Walker              Rob Walker
# ..                     ...                   ...                     ...
# 524            Jim Strouse      Jessica Williams            Chris O'Dowd
# 525            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 526       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 527  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 529           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#              actor_3_name                           genres  \
# ...

# %%
#saving the data
new.to_csv('new_data.csv',index=False)

# %%
# grab movie data on wiki from 2018 to 2022

for i in range(2018, 2023):
  exec(f'link_{i} = "https://en.wikipedia.org/wiki/List_of_American_films_of_{i}"')
  exec(f'source_{i} = urllib.request.urlopen(link_{i}).read()')
  exec(f'soup_{i} = bs.BeautifulSoup(source_{i},"lxml")')

# %%
# trans into dataframe
for i in range(2018, 2023):
  exec(f'tables_{i} = soup_{i}.find_all("table",class_="wikitable sortable")')
  exec(f'df1_{i} = pd.read_html(str(tables_{i}[0]))[0]')
  exec(f'df2_{i} = pd.read_html(str(tables_{i}[1]))[0]')
  exec(f'df3_{i} = pd.read_html(str(tables_{i}[2]))[0]')

# avoided "ValueError: invalid literal for int() with base 10: '1"'
df4_2018 = pd.read_html(str(tables_2018[3]).replace("'1\"\'",'"1"'))[0] 
df4_2019 = pd.read_html(str(tables_2019[3]).replace("'1\"\'",'"1"'))[0] 
df4_2020 = pd.read_html(str(tables_2020[3]).replace("'1\"\'",'"1"'))[0] 
df4_2021 = pd.read_html(str(tables_2021[3]).replace("'1\"\'",'"1"'))[0] 
df4_2022 = pd.read_html(str(tables_2022[3]).replace("'1\"\'",'"1"'))[0] 



# append them all and select needed data
for i in range(2018, 2023):
  exec(f'df_{i} = df1_{i}.append(df2_{i}.append(df3_{i}.append(df4_{i},ignore_index=True),ignore_index=True),ignore_index=True)')
  exec(f'df_{i} = df_{i}[["Title","Cast and crew"]]')

# %%
# combine them all
df_all = df_2018.append(df_2019.append(df_2020.append(df_2021.append(df_2022,ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df_all
# Out:
#                         Title  \
# 0     Insidious: The Last Key
# 1            The Strange Ones
# 2                    Stratton
# 3               Sweet Country
# 4                The Commuter
# ...                       ...
# 1480           Alice, Darling
# 1481                      NaN
# 1482                      NaN
# 1483                      NaN
# 1484                      NaN
#
#                                                                    Cast and crew
# 0     Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus ...
# 1     Lauren Wolkstein (director); Christopher Radcliff (co-director/screenpl...
# 2     Simon West (director); Duncan Falconer, Warren Davis II (screenplay); D...
# 3     Warwick Thornton (director); David Tranter, Steven McGregor (screenplay...
# 4     Jaume Collet-Serra (director); Byron Willinger, Philip de Blasi (screen...
# ...                                                                          ...
# ...

# %%
# install tmdbv3api
# !pip install tmdbv3api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# now we collect genres from TMDb database
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '8306a2c064c0db7202d1d0970f58dd0c'

# %%
# create function
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
# applying
df_all['genres'] = df_all['Title'].map(lambda x: get_genre(str(x)))

# %%
# checking 
df_all
# Out:
#                         Title  \
# 0     Insidious: The Last Key
# 1            The Strange Ones
# 2                    Stratton
# 3               Sweet Country
# 4                The Commuter
# ...                       ...
# 1480           Alice, Darling
# 1481                      NaN
# 1482                      NaN
# 1483                      NaN
# 1484                      NaN
#
#                                                                    Cast and crew  \
# 0     Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus ...
# 1     Lauren Wolkstein (director); Christopher Radcliff (co-director/screenpl...
# 2     Simon West (director); Duncan Falconer, Warren Davis II (screenplay); D...
# 3     Warwick Thornton (director); David Tranter, Steven McGregor (screenplay...
# 4     Jaume Collet-Serra (director); Byron Willinger, Philip de Blasi (screen...
# ...                                                                          ...
# ...

# %%
# function for sperate director, actor1 and so on
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_all['director_name'] = df_all['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_all['actor_1_name'] = df_all['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_all['actor_2_name'] = df_all['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_all['actor_3_name'] = df_all['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
# checking
df_all
# Out:
#                         Title  \
# 0     Insidious: The Last Key
# 1            The Strange Ones
# 2                    Stratton
# 3               Sweet Country
# 4                The Commuter
# ...                       ...
# 1480           Alice, Darling
# 1481                      NaN
# 1482                      NaN
# 1483                      NaN
# 1484                      NaN
#
#                                                                    Cast and crew  \
# 0     Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus ...
# 1     Lauren Wolkstein (director); Christopher Radcliff (co-director/screenpl...
# 2     Simon West (director); Duncan Falconer, Warren Davis II (screenplay); D...
# 3     Warwick Thornton (director); David Tranter, Steven McGregor (screenplay...
# 4     Jaume Collet-Serra (director); Byron Willinger, Philip de Blasi (screen...
# ...                                                                          ...
# ...

# %%
# rename
df_all = df_all.rename(columns={'Title':'movie_title'})

# %%
# select needed variable
new_df_all = df_all.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df_all
# Out:
#            director_name    actor_1_name            actor_2_name  \
# 0           Adam Robitel       Lin Shaye           Angus Sampson
# 1       Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson
# 2             Simon West  Dominic Cooper          Austin Stowell
# 3       Warwick Thornton     Bryan Brown               Sam Neill
# 4     Jaume Collet-Serra     Liam Neeson            Vera Farmiga
# ...                  ...             ...                     ...
# 1480          Mary Nighy   Anna Kendrick         Kaniehtiio Horn
# 1481                 nan             nan                     NaN
# 1482                 nan             nan                     NaN
# 1483                 nan             nan                     NaN
# 1484                 nan             nan                     NaN
#
#          actor_3_name                   genres              movie_title
# 0      Leigh Whannell  Horror Mystery Thriller  Insidious: The Last Key
# ...

# %%
# gen comb
new_df_all['comb'] = new_df_all['actor_1_name'] + ' ' + new_df_all['actor_2_name'] + ' '+ new_df_all['actor_3_name'] + ' '+ new_df_all['director_name'] +' ' + new_df_all['genres']

# %%
# checking and drop missing value
new_df_all.isna().sum()
# Out:
# director_name      0
# actor_1_name       0
# actor_2_name      35
# actor_3_name     136
# genres             5
# movie_title        5
# comb             140
# dtype: int64

# %%
new_df_all = new_df_all.dropna(how='any')

# %%
new_df_all.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
# lower cap for title
new_df_all['movie_title'] = new_df_all['movie_title'].str.lower()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_df_all
# Out:
#            director_name      actor_1_name            actor_2_name  \
# 0           Adam Robitel         Lin Shaye           Angus Sampson
# 1       Lauren Wolkstein     Alex Pettyfer  James Freedson-Jackson
# 2             Simon West    Dominic Cooper          Austin Stowell
# 4     Jaume Collet-Serra       Liam Neeson            Vera Farmiga
# 5           Babak Najafi  Taraji P. Henson             Billy Brown
# ...                  ...               ...                     ...
# 1476        Sarah Polley       Rooney Mara              Claire Foy
# 1477        Scott Cooper    Christian Bale           Harry Melling
# 1478        Marc Forster         Tom Hanks         Mariana Treviño
# 1479         Juel Taylor       John Boyega          Teyonah Parris
# 1480          Mary Nighy     Anna Kendrick         Kaniehtiio Horn
#
#            actor_3_name                          genres  \
# 0        Leigh Whannell         Horror Mystery Thriller
# ...

# %%
# combine two dataset
old_df = pd.read_csv('new_data.csv')

# %%
old_df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                               movie_title  \
# 0                                                  avatar
# 1                pirates of the caribbean: at world's end
# 2                                                 spectre
# ...

# %%
final_df = old_df.append(new_df_all,ignore_index=True)

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6704       Sarah Polley      Rooney Mara        Claire Foy
# 6705       Scott Cooper   Christian Bale     Harry Melling
# 6706       Marc Forster        Tom Hanks   Mariana Treviño
# 6707        Juel Taylor      John Boyega    Teyonah Parris
# 6708         Mary Nighy    Anna Kendrick   Kaniehtiio Horn
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
# saving
final_df.to_csv('main_data.csv',index=False)
